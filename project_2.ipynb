# %%
url="C:/Users/USER/OneDrive/Desktop/project_2/OLA_DataSet.xlsx"

# %%
import pandas as pd
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel(url)

# %%
df.head(5)
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
# Data exploration
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[ns]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
# ...

# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.describe()
# Out:
#                                 Date         V_TAT         C_TAT  \
# count                         103024  63967.000000  63967.000000
# mean   2024-07-16 11:31:38.879678720    170.876952     84.873372
# min              2024-07-01 00:00:00     35.000000     25.000000
# 25%              2024-07-08 18:41:00     98.000000     55.000000
# 50%              2024-07-16 11:23:00    168.000000     85.000000
# 75%              2024-07-24 05:18:00    238.000000    115.000000
# max              2024-07-31 23:58:00    308.000000    145.000000
# std                              NaN     80.803640     36.005100
#
#        Booking_Value  Ride_Distance  Driver_Ratings  Customer_Rating
# count  103024.000000  103024.000000    63967.000000     63967.000000
# mean      548.751883      14.189927        3.997457         3.998313
# min       100.000000       0.000000        3.000000         3.000000
# 25%       242.000000       0.000000        3.500000         3.500000
# ...

# %%
# Handling missing values
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# Vehicle Images                    0
# dtype: int64

# %%
100*df.isnull().sum()/df.shape[0]
# Out:
# Date                           0.000000
# Time                           0.000000
# Booking_ID                     0.000000
# Booking_Status                 0.000000
# Customer_ID                    0.000000
# Vehicle_Type                   0.000000
# Pickup_Location                0.000000
# Drop_Location                  0.000000
# V_TAT                         37.910584
# C_TAT                         37.910584
# Canceled_Rides_by_Customer    89.809171
# Canceled_Rides_by_Driver      82.107082
# Incomplete_Rides              37.910584
# Incomplete_Rides_Reason       96.189237
# Booking_Value                  0.000000
# Payment_Method                37.910584
# Ride_Distance                  0.000000
# Driver_Ratings                37.910584
# Customer_Rating               37.910584
# Vehicle Images                 0.000000
# dtype: float64

# %%
plt.boxplot(df["V_TAT"])
plt.show()

# %%
df["V_TAT"].describe()
# Out:
# count    63967.000000
# mean       170.876952
# std         80.803640
# min         35.000000
# 25%         98.000000
# 50%        168.000000
# 75%        238.000000
# max        308.000000
# Name: V_TAT, dtype: float64

# %%
df["V_TAT"] = df["V_TAT"].fillna(df["V_TAT"].median())

# %%
plt.boxplot(df["C_TAT"])
plt.show()

# %%
df["C_TAT"] = df["C_TAT"].fillna(df["C_TAT"].median())

# %%
# Clean 'Canceled_Rides_by_Customer' using mode
mode_value = df['Canceled_Rides_by_Customer'].mode()[0]   # get the most frequent value
df['Canceled_Rides_by_Customer'].fillna(mode_value, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16476\4273388734.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Canceled_Rides_by_Customer'].fillna(mode_value, inplace=True)

# %%
# Clean 'Canceled_Rides_by_Driver' using mode
mode_driver = df['Canceled_Rides_by_Driver'].mode()[0]   # most frequent value
df['Canceled_Rides_by_Driver'].fillna(mode_driver, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16476\2498931784.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Canceled_Rides_by_Driver'].fillna(mode_driver, inplace=True)

# %%
df['Incomplete_Rides'] = df['Incomplete_Rides'].fillna(df['Incomplete_Rides'].mode()[0])

# %%
# Clean 'Incomplete_Rides_Reason' using mode
mode_reason = df['Incomplete_Rides_Reason'].mode()[0]   # most frequent value
df['Incomplete_Rides_Reason'].fillna(mode_reason, inplace=True)

# %%
# Clean 'Payment_Method' using mode
mode_payment = df['Payment_Method'].mode()[0]   # most frequent value
df['Payment_Method'].fillna(mode_payment, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16476\2359416264.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Payment_Method'].fillna(mode_payment, inplace=True)

# %%
plt.boxplot(df["Driver_Ratings"])
plt.title("Boxplot of Driver Ratings")
plt.ylabel("Ratings")
plt.show()

# %%
df["Driver_Ratings"].describe()
# Out:
# count    63967.000000
# mean         3.997457
# std          0.576834
# min          3.000000
# 25%          3.500000
# 50%          4.000000
# 75%          4.500000
# max          5.000000
# Name: Driver_Ratings, dtype: float64

# %%
# Clean 'Driver_Ratings' using median
median_driver = df["Driver_Ratings"].median()
df["Driver_Ratings"].fillna(median_driver, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16476\3958155400.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Driver_Ratings"].fillna(median_driver, inplace=True)

# %%
plt.boxplot(df["Customer_Rating"])
plt.title("Boxplot of Customer Rating")
plt.ylabel("Ratings")
plt.show()

# %%
df["Customer_Rating"].describe()
# Out:
# count    63967.000000
# mean         3.998313
# std          0.578957
# min          3.000000
# 25%          3.500000
# 50%          4.000000
# 75%          4.500000
# max          5.000000
# Name: Customer_Rating, dtype: float64

# %%
# Clean 'Customer_Rating' using median
median_customer = df["Customer_Rating"].median()
df["Customer_Rating"].fillna(median_customer, inplace=True)

# Verify changes
print(df["Customer_Rating"].isnull().sum())
print(df["Customer_Rating"].describe())
# Out:
# 0
# count    103024.000000
# mean          3.998953
# std           0.456199
# min           3.000000
# 25%           3.800000
# 50%           4.000000
# 75%           4.200000
# max           5.000000
# Name: Customer_Rating, dtype: float64
# C:\Users\USER\AppData\Local\Temp\ipykernel_16476\904172561.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Customer_Rating"].fillna(median_customer, inplace=True)

# %%
df=pd.read_excel(url)

# %%
df.head(5)
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar  168.0   85.0
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar  168.0   85.0
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
#  fill numeric columns with median
df['V_TAT'] = df['V_TAT'].fillna(df['V_TAT'].median())
df['C_TAT'] = df['C_TAT'].fillna(df['C_TAT'].median())

#  fill categorical columns with mode
df['Canceled_Rides_by_Customer'] = df['Canceled_Rides_by_Customer'].fillna(df['Canceled_Rides_by_Customer'].mode()[0])
df['Canceled_Rides_by_Driver'] = df['Canceled_Rides_by_Driver'].fillna(df['Canceled_Rides_by_Driver'].mode()[0])
df['Incomplete_Rides_Reason'] = df['Incomplete_Rides_Reason'].fillna(df['Incomplete_Rides_Reason'].mode()[0])
df['Payment_Method'] = df['Payment_Method'].fillna(df['Payment_Method'].mode()[0])
df['Driver_Ratings'] = df['Driver_Ratings'].fillna(df['Driver_Ratings'].median())  # numeric
df['Customer_Rating'] = df['Customer_Rating'].fillna(df['Customer_Rating'].median())  # numeric

# %%
# Handling missing values
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# Vehicle Images                    0
# dtype: int64

# %%
# Handling missing values
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# Vehicle Images                    0
# dtype: int64

# %%
# 1. Confirm which DataFrame you're checking
df.info()

# 2. Look at unique values in a problematic column
df['Incomplete_Rides_Reason'].unique()

# 3. Force replacement of common placeholders
df.replace(["NA", "null", "?", ""], np.nan, inplace=True)

# 4. Re-run your cleaning logic
df.fillna(df.median(numeric_only=True), inplace=True)
df.fillna(df.mode().iloc[0], inplace=True)

# 5. Verify again
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[ns]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  103024 non-null  object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# Vehicle Images                0
# dtype: int64

# %%
import mysql.connector
import pandas as pd
import streamlit as st
from pathlib import Path
import numpy as np


# Step 1: Connect to MySQL
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Puchib763@',   # replace with your password
    port=3307,                # adjust if needed
    database='ola' # confirmed to exist
)

# Step 2: Verify connection
if connection.is_connected():
    print("Connected to MySQL!")

# Step 3: Create a cursor
cursor = connection.cursor()



# Relative path (file inside project_1 folder)
rel_path = Path("OLA_DataSet.xlsx")

# Load into pandas
df = pd.read_excel(rel_path)

print(df.head())
# Out:
# Connected to MySQL!
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
# SQL query to create the table
create_table_query = """
CREATE TABLE IF NOT EXISTS ola_data (
    Date DATETIME,
    Time TIME,
    Booking_ID VARCHAR(50),
    Booking_Status VARCHAR(100),
    Customer_ID VARCHAR(50),
    Vehicle_Type VARCHAR(50),
    Pickup_Location VARCHAR(100),
    Drop_Location VARCHAR(100),
    V_TAT FLOAT,
    C_TAT FLOAT,
    Canceled_Rides_by_Driver INT,
    Canceled_Rides_by_User INT,
    Personal_Car_Related_Issue VARCHAR(255),
    Payment_Mode VARCHAR(50),
    Feedback VARCHAR(255),
    Ratings FLOAT,
    Driver_ID VARCHAR(50),
    User_ID VARCHAR(50),
    Distance FLOAT,
    Amount FLOAT
);
"""

# Execute the query
cursor.execute(create_table_query)
connection.commit()

print("Table created successfully!")
# Out:
# Table created successfully!

# %%
cursor.executemany(insert_query, rows[:5])  # insert first 5 rows
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Incorrect integer value: 'Personal & Car related issue' for column 'Canceled_Rides_by_Driver' at row 1
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[12], line 1
# ...

# %%
# Convert to numeric, force text to NaN
df["Canceled_Rides_by_Driver"] = pd.to_numeric(df["Canceled_Rides_by_Driver"], errors="coerce")

# Replace NaN with 0 (or None if you want NULL in MySQL)
df["Canceled_Rides_by_Driver"] = df["Canceled_Rides_by_Driver"].fillna(0).astype(int)

# %%
rows = [tuple(x) for x in df.to_numpy()]
cursor.executemany(insert_query, rows)
connection.commit()
print("Inserted:", cursor.rowcount, "rows")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Incorrect integer value: 'No' for column 'Incomplete_Rides' at row 2
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[14], line 2
# ...

# %%
# Force conversion to numeric
df["Canceled_Rides_by_Driver"] = pd.to_numeric(df["Canceled_Rides_by_Driver"], errors="coerce")

# Replace NaN with 0 (or None if you want NULL in MySQL)
df["Canceled_Rides_by_Driver"] = df["Canceled_Rides_by_Driver"].fillna(0).astype(int)

# Now build rows AFTER cleaning
rows = [tuple(x) for x in df.to_numpy()]

# %%
print(df["Canceled_Rides_by_Driver"].unique()[:10])
print(df["Canceled_Rides_by_Driver"].dtype)
# Out:
# [0]
# int64

# %%
numeric_columns = [
    "Canceled_Rides_by_Driver",
    "Canceled_Rides_by_Customer",   # adjust to your actual column names
    "Incomplete_Rides",
    "V_TAT", "C_TAT", "Booking_Value",
    "Ride_Distance", "Driver_Ratings", "Customer_Rating", "Amount"
]

for col in numeric_columns:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

# %%
print(df.dtypes)
# Out:
# Date                          datetime64[ns]
# Time                                  object
# Booking_ID                            object
# Booking_Status                        object
# Customer_ID                           object
# Vehicle_Type                          object
# Pickup_Location                       object
# Drop_Location                         object
# V_TAT                                  int64
# C_TAT                                  int64
# Canceled_Rides_by_Customer             int64
# Canceled_Rides_by_Driver               int64
# Incomplete_Rides                       int64
# Incomplete_Rides_Reason               object
# Booking_Value                          int64
# Payment_Method                        object
# Ride_Distance                          int64
# Driver_Ratings                         int64
# Customer_Rating                        int64
# Vehicle Images                        object
# dtype: object

# %%
rows = [tuple(x) for x in df.to_numpy()]
cursor.executemany(insert_query, rows)
connection.commit()
print("Inserted:", cursor.rowcount, "rows")
# Out:
# Inserted: 103024 rows
